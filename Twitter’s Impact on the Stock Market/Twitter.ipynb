# %%
import tweepy,json

access_token="187482643-E1Y85v7RjcibiPULqxJcYSqbdGFkZg6q3k9fmQ3q"
access_token_secret="G51ey12KIwDME92tg7pXAqZqzqToiZfSmL9LC0QGxUi3n"
consumer_key="QwA6A8TjodzlE2XahxsB54l98"
consumer_secret="GpdeAdTHG1CQFU0HGjtskHHuRP7CJUME1e5wD5HVfcQgsLlen9"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAL5piAEAAAAAmsn0I8SUSbLzFE2NsjVPrRAutIk%3DA5qbR3BekkDecu1RaejlfjwmLDZKB4oxR0dnxprsftf11EjuLT"

client = tweepy.Client(bearer_token,consumer_key,consumer_secret,access_token,access_token_secret)

query = 'from:suhemparack -is:retweet'

# Replace with time period of your choice
start_time = '2020-01-01T00:00:00Z'

# Replace with time period of your choice
end_time = '2020-08-01T00:00:00Z'

tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                  start_time=start_time,
                                  end_time=end_time, max_results=100)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Input In [1], in <cell line: 19>()
#      16 # Replace with time period of your choice
#      17 end_time = '2020-08-01T00:00:00Z'
# ---> 19 tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
#      20                                   start_time=start_time,
#      21                                   end_time=end_time, max_results=100)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tweepy/client.py:1145, in Client.search_all_tweets(self, query, **params)
#    1053 """search_all_tweets( \
#    1054     query, *, end_time=None, expansions=None, max_results=None, \
#    1055     media_fields=None, next_token=None, place_fields=None, \
#    (...)
# ...

# %%
import tweepy,json

access_token="187482643-E1Y85v7RjcibiPULqxJcYSqbdGFkZg6q3k9fmQ3q"
access_token_secret="G51ey12KIwDME92tg7pXAqZqzqToiZfSmL9LC0QGxUi3n"
consumer_key="QwA6A8TjodzlE2XahxsB54l98"
consumer_secret="GpdeAdTHG1CQFU0HGjtskHHuRP7CJUME1e5wD5HVfcQgsLlen9"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAL5piAEAAAAAmsn0I8SUSbLzFE2NsjVPrRAutIk%3DA5qbR3BekkDecu1RaejlfjwmLDZKB4oxR0dnxprsftf11EjuLT"

client = tweepy.Client(bearer_token,consumer_key,consumer_secret,access_token,access_token_secret)

hoax_tweets = []
for response in tweepy.Paginator(client.search_recent_tweets, 
                                 query = 'COVID hoax -is:retweet lang:en',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 expansions = 'author_id',
                                 start_time = '2022-10-08T00:00:00Z',
                                 end_time = '2022-10-11T00:00:00Z',
                              max_results=10):
    
    hoax_tweets.append(response)

hoax_tweets[0].data[0]
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Input In [12], in <cell line: 12>()
#       9 client = tweepy.Client(bearer_token,consumer_key,consumer_secret,access_token,access_token_secret)
#      11 hoax_tweets = []
# ---> 12 for response in tweepy.Paginator(client.search_recent_tweets,
#      13                                  query = 'COVID hoax -is:retweet lang:en',
#      14                                  user_fields = ['username', 'public_metrics', 'description', 'location'],
#      15                                  tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
#      16                                  expansions = 'author_id',
#      17                                  start_time = '2022-10-08T00:00:00Z',
#      18                                  end_time = '2022-10-11T00:00:00Z',
#      19                               max_results=10):
# ...
